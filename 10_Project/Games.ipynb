# %% [markdown]
# # Number Guessing Game

# %%
import random

print("Hi! Welcome to the Number Guessing Game. \nYou have 7 chances to guess the number. Let's start!")

low = int(input("Enter the Lower Bound: "))
high = int(input("Enter the Upper Bound: "))

print(f"You have 7 chances to guess the number between {low} and {high}. Let's GO!")

num = random.randint(low, high)
ch = 7   # Total guesses allowed
gc = 0   # Guess count

while gc < ch:
    gc += 1
    guess = int(input('Enter your guess: '))
    
    if guess == num:
        print(f'🎉 Correct! The number is {num}. You guessed it in {gc} attempts.')
        break
    elif guess > num:
        print('Too high! Try a lower number.')
    elif guess < num:
        print('Too low! Try a higher number.')

# If loop ends without a correct guess
else:
    print(f'❌ Sorry! The number was {num}. Better luck next time.')
# Out:
# Hi! Welcome to the Number Guessing Game.
# You have 7 chances to guess the number. Let's start!
# You have 7 chances to guess the number between 1 and 10. Let's GO!
# Too high! Try a lower number.
# Too low! Try a higher number.
# 🎉 Correct! The number is 3. You guessed it in 3 attempts.

# %% [markdown]
# # Rock, Paper, Scissors 🪨📰✂️

# %%
import random

options = ['r', 'p', 's']
player = None
computer = random.choice(options)

player = input("Enter your (r, p, s) choice (rock, paper, scissors): ").lower()
if player not in options:
    print("Invalid choice! Please choose rock, paper, or scissors.")
else:
    print(f"Computer chose: {computer}")

    if player == computer:
        print("It's a tie!")
    elif (player == 'r' and computer == 's') or \
         (player == 'p' and computer == 'r') or \
         (player == 's' and computer == 'p'):
        print("You win!")
    else:
        print("You lose!")
# Out:
# Computer chose: r
# You win!

# %% [markdown]
# # Quiz Game 💯

# %%
questions = (
    "1. What is the capital of France?: ",
    "2. Which planet is known as the Red Planet?: ",
    "3. What is the largest mammal in the world?: ",
    "4. How many elements are there in the periodic table?: ",
    "5. Which language is primarily used for web development?: ",
    "6. What is the smallest prime number?: ",
    "7. Who wrote 'Romeo and Juliet'?: ",
    "8. What is the hardest natural substance on Earth?: ",
    "9. What is the chemical symbol for gold?: ",
    "10. Who painted the Mona Lisa?: ",
    "11. Who write the song 'For a Reason'?: ",
    "12. What is a LOVE?: "
    )
options = (
    ["A. Paris", "B. London", "C. Berlin", "D. Madrid"],
    ["A. Earth", "B. Mars", "C. Jupiter", "D. Saturn"],
    ["A. Elephant", "B. Blue Whale", "C. Giraffe", "D. Great White Shark"],
    ["A. 102", "B. 118", "C. 120", "D. 110"],
    ["A. Python", "B. Java", "C. HTML", "D. C++"],
    ["A. 0", "B. 1", "C. 2", "D. 3"],
    ["A. Charles Dickens", "B. William Shakespeare", "C. Mark Twain", "D. Jane Austen"],
    ["A. Diamond", "B. Gold", "C. Iron", "D. Silver"],
    ["A. Au", "B. Ag", "C. Fe", "D. Pb"],
    ["A. Vincent van Gogh", "B. Pablo Picasso", "C. Leonardo da Vinci", "D. Claude Monet"],
    ["A. Ed Sheeran", "B. Taylor Swift", "C. Karan Aujla", "D. Bruno Mars"],
    ["A. Emotion", "B. Feeling", "C. Action", "D. All of the above"]
    )
answers = ("A", "B", "B", "B", "C", "C", "B", "A", "A", "C", "C", "D")
guesses = []
score = 0
question_num = 0

for question in questions:
    print("-------------------------------")
    print(question)
    for option in options[question_num]:
        print(option)
    guess = input("Enter (A, B, C, or D): ").upper()
    guesses.append(guess)
    if guess == answers[question_num]:
        score += 1
    question_num += 1
print("-------------------------------")
print("Quiz Completed!")
print(f"Your score is {score} out of {len(questions)}")
print("Thanks for playing!")
# Out:
# -------------------------------
# 1. What is the capital of France?:
# A. Paris
# B. London
# C. Berlin
# D. Madrid
# -------------------------------
# 2. Which planet is known as the Red Planet?:
# A. Earth
# B. Mars
# C. Jupiter
# D. Saturn
# -------------------------------
# 3. What is the largest mammal in the world?:
# A. Elephant
# B. Blue Whale
# C. Giraffe
# D. Great White Shark
# -------------------------------
# 4. How many elements are there in the periodic table?:
# A. 102
# B. 118
# C. 120
# D. 110
# -------------------------------
# 5. Which language is primarily used for web development?:
# A. Python
# B. Java
# C. HTML
# D. C++
# -------------------------------
# 6. What is the smallest prime number?:
# A. 0
# B. 1
# C. 2
# D. 3
# -------------------------------
# 7. Who wrote 'Romeo and Juliet'?:
# A. Charles Dickens
# B. William Shakespeare
# C. Mark Twain
# D. Jane Austen
# -------------------------------
# 8. What is the hardest natural substance on Earth?:
# ...

# %% [markdown]
# # Madlibs Game
# Word game where you create a story by filling in blanks with random words

# %%
adjective1 = input("Enter an adjective (description): ")
noun1 = input("Enter a noun (person, place, thing): ")
adjective2 = input("Enter an adjective (description): ")
verb1 = input("Enter a verb ending with 'ing': ")
adjective3 = input("Enter an adjective (description): ")

print(f"Today I went to a {adjective1} zoo.")
print(f"In an exhibit, I saw a {noun1}")
print(f"{noun1} was {adjective2} and {verb1}")
print(f"I was {adjective3}!")
